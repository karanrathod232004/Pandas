# %%
import pandas as pd

# %%
#Create dataframe use python list 
information = [["karan",99],["priya",78],["jack",56],["mik",88]]
df = pd.DataFrame(information,columns=["Name","Marks"])
df
# Out:
#     Name  Marks
# 0  karan     99
# 1  priya     78
# 2   jack     56
# 3    mik     88

# %%
#Create data frame and use list and dictionery
employe_data = {
    "Name":["Rahul","Ruhanika","Jack","Michael"],
    "Department":["Ai-ml","Data-science","Business-analysis","Python-devlopar"],
    "Salary":[90000,87000,56000,54000],
}
df = pd.DataFrame(employe_data,index=[101,102,103,104])
df
# Out:
#          Name         Department  Salary
# 101     Rahul              Ai-ml   90000
# 102  Ruhanika       Data-science   87000
# 103      Jack  Business-analysis   56000
# 104   Michael    Python-devlopar   54000

# %%
#read json 
df = pd.read_json("data.json.txt")
print(df)
# Out:
#      Name  Age                Clg_name
# 0   karan   21  Gandhinagar_university
# 1  Shreya   20  Gandhinagar_university

# %% [markdown]
# #read excel file
# #chack (head,tail,info,describe,columns,shape)

# %%
excel_data = pd.read_excel(r"C:\Users\Ridhi Rathore\Downloads\Amazon_Sales_Dashboard_Practice.xlsx")
excel_data
# Out:
#      Order_ID  Order_Date Customer        State       City     Category  \
# 0        1001  11-06-2025    Sneha      Gujarat      Surat        Books
# 1        1002  27-03-2025    Aarav    Rajasthan     Jaipur      Fashion
# 2        1003  06-03-2025    Sneha    Rajasthan     Jaipur      Fashion
# 3        1004  23-03-2025    Karan        Delhi  New Delhi  Electronics
# 4        1005  22-05-2025   Vivaan  Maharashtra     Mumbai  Electronics
# ..        ...         ...      ...          ...        ...          ...
# 145      1146  13-06-2025    Karan        Delhi  New Delhi  Electronics
# 146      1147  26-05-2025    Karan        Delhi  New Delhi        Books
# 147      1148  01-04-2025    Rahul        Delhi  New Delhi  Electronics
# 148      1149  21-03-2025    Priya  Maharashtra     Mumbai  Electronics
# 149      1150  04-01-2025    Rahul        Delhi  New Delhi         Home
#
#          Product  Quantity  Unit_Price   Sales  Profit    Payment_Method  \
# ...

# %%
excel_data.head()
# Out:
#    Order_ID  Order_Date Customer        State       City     Category  \
# 0      1001  11-06-2025    Sneha      Gujarat      Surat        Books
# 1      1002  27-03-2025    Aarav    Rajasthan     Jaipur      Fashion
# 2      1003  06-03-2025    Sneha    Rajasthan     Jaipur      Fashion
# 3      1004  23-03-2025    Karan        Delhi  New Delhi  Electronics
# 4      1005  22-05-2025   Vivaan  Maharashtra     Mumbai  Electronics
#
#        Product  Quantity  Unit_Price   Sales  Profit    Payment_Method  \
# 0  Python Book         2         800    1600     192               UPI
# 1       Jacket         4        4000   16000    2400       Credit Card
# 2       Jacket         2        4000    8000    1280  Cash on Delivery
# 3       iPhone         5       70000  350000   38500  Cash on Delivery
# 4  Samsung S24         4       60000  240000   33600        Debit Card
#
#   Delivery_Status
# 0        Returned
# 1       Cancelled
# 2       Delivered
# 3         Shipped
# 4       Cancelled

# %%
excel_data.tail()
# Out:
#      Order_ID  Order_Date Customer        State       City     Category  \
# 145      1146  13-06-2025    Karan        Delhi  New Delhi  Electronics
# 146      1147  26-05-2025    Karan        Delhi  New Delhi        Books
# 147      1148  01-04-2025    Rahul        Delhi  New Delhi  Electronics
# 148      1149  21-03-2025    Priya  Maharashtra     Mumbai  Electronics
# 149      1150  04-01-2025    Rahul        Delhi  New Delhi         Home
#
#          Product  Quantity  Unit_Price   Sales  Profit    Payment_Method  \
# 145       Laptop         5       55000  275000   27500  Cash on Delivery
# 146  Python Book         2         800    1600     272        Debit Card
# 147  Samsung S24         5       60000  300000   51000               UPI
# 148       Laptop         1       55000   55000    6050        Debit Card
# 149        Mixer         1        3500    3500     525        Debit Card
#
#     Delivery_Status
# 145       Cancelled
# 146        Returned
# 147        Returned
# ...

# %%
excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         150 non-null    int64
#  1   Order_Date       150 non-null    object
#  2   Customer         150 non-null    object
#  3   State            150 non-null    object
#  4   City             150 non-null    object
#  5   Category         150 non-null    object
#  6   Product          150 non-null    object
#  7   Quantity         150 non-null    int64
#  8   Unit_Price       150 non-null    int64
#  9   Sales            150 non-null    int64
#  10  Profit           150 non-null    int64
#  11  Payment_Method   150 non-null    object
#  12  Delivery_Status  150 non-null    object
# dtypes: int64(5), object(8)
# memory usage: 15.4+ KB

# %%
#Chack and count null value 
excel_data.isnull().sum()  #No nun(mising value )value
# Out:
# Order_ID           0
# Order_Date         0
# Customer           0
# State              0
# City               0
# Category           0
# Product            0
# Quantity           0
# Unit_Price         0
# Sales              0
# Profit             0
# Payment_Method     0
# Delivery_Status    0
# dtype: int64

# %%
excel_data.describe()
# Out:
#           Order_ID    Quantity    Unit_Price          Sales        Profit
# count   150.000000  150.000000    150.000000     150.000000    150.000000
# mean   1075.500000    3.053333  16604.666667   52960.666667   7342.253333
# std      43.445368    1.527320  24844.633565   94275.012273  13532.353872
# min    1001.000000    1.000000    650.000000     650.000000     52.000000
# 25%    1038.250000    2.000000    800.000000    3250.000000    422.750000
# 50%    1075.500000    3.000000   3500.000000   10000.000000   1270.000000
# 75%    1112.750000    5.000000   9000.000000   36000.000000   4312.500000
# max    1150.000000    5.000000  70000.000000  350000.000000  59500.000000

# %%
excel_data.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer', 'State', 'City', 'Category',
#        'Product', 'Quantity', 'Unit_Price', 'Sales', 'Profit',
#        'Payment_Method', 'Delivery_Status'],
#       dtype='object')

# %%
excel_data.shape
# Out:
# (150, 13)

# %% [markdown]
# Read CSV file
# And chack EDA(Exploratory Data Analysis)

# %%
Netflix_data = pd.read_csv(r"C:\Users\Ridhi Rathore\Downloads\NetFlix.csv.zip")

# %%
#Chack first 5 rows
Netflix_data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
#Chack last 5 rows
Netflix_data.tail()
# Out:
#      show_id     type                      title             director  \
# 7782    s995  TV Show                 Blown Away                  NaN
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast  \
# 7782                                                NaN
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# ...

# %%
#Chack information of data
Netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
#Chack and count nun value 
Netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
#Chack describe
Netflix_data.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
#Chack columns name 
Netflix_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %%
#Chack data shape
Netflix_data.shape
# Out:
# (7787, 12)

# %%
#Chack size
Netflix_data.size
# Out:
# 93444

# %%
#Only practice csv and use EDA(Exploratory data analysis)
df = pd.read_csv(r"C:\Users\Ridhi Rathore\Downloads\Iris.csv")

# %%
#Chack top 5 rows
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Chack last 5 rows 
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#Chack information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Chack describe
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Chack columns
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#chack shape 
df.shape
# Out:
# (150, 6)

# %%
#Chack total null value
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
