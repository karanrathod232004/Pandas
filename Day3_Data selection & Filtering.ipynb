# %%
import pandas as pd
import numpy as np

# %%
#Read excel data
df = pd.read_excel(r"C:\Users\Ridhi Rathore\Downloads\pandas_data_selection_filtering_practice.xlsx")
df
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0         1001   Aarav         IT   55000           2
# 1         1002    Diya         HR   48000           1
# 2         1003   Rohan    Finance   62000           4
# 3         1004   Anaya         IT   70000           5
# 4         1005  Vivaan      Sales   45000           1
# 5         1006  Ishita         HR   52000           3
# 6         1007  Aditya    Finance   68000           4
# 7         1008    Myra  Marketing   58000           2
# 8         1009   Arjun         IT   75000           6
# 9         1010   Kiara      Sales   50000           2

# %%
#Select name columns
df["Name"]
# Out:
# 0     Aarav
# 1      Diya
# 2     Rohan
# 3     Anaya
# 4    Vivaan
# 5    Ishita
# 6    Aditya
# 7      Myra
# 8     Arjun
# 9     Kiara
# Name: Name, dtype: object

# %%
#Select 2 columns name and salary 
df[["Name","Salary"]]
# Out:
#      Name  Salary
# 0   Aarav   55000
# 1    Diya   48000
# 2   Rohan   62000
# 3   Anaya   70000
# 4  Vivaan   45000
# 5  Ishita   52000
# 6  Aditya   68000
# 7    Myra   58000
# 8   Arjun   75000
# 9   Kiara   50000

# %%
#Select row and colums Employe_id 1009 
df.loc[8]
# Out:
# Employee_ID     1009
# Name           Arjun
# Department        IT
# Salary         75000
# Experience         6
# Name: 8, dtype: object

# %%
#Select  Employe_id 1004 only get salary columns
df.loc[3,["Salary"]]
# Out:
# Salary    70000
# Name: 3, dtype: object

# %%
#Select first row use iloc
df.iloc[0]
# Out:
# Employee_ID     1001
# Name           Aarav
# Department        IT
# Salary         55000
# Experience         2
# Name: 0, dtype: object

# %%
#Select 5th row and only Name column
df.iloc[5,1]
# Out:
# 'Ishita'

# %%
#use loc select employe_id 1003 and 1007 and column only name and salary 
df.loc[[2,6],["Employee_ID","Name","Salary"]]
# Out:
#    Employee_ID    Name  Salary
# 2         1003   Rohan   62000
# 6         1007  Aditya   68000

# %%
#(at) use Find the salary of employee_id 1009
df.at[8,"Salary"]
# Out:
# np.int64(75000)

# %%
#(iat) Find the salary of the 3rd employe 
df.iat[2,3]
# Out:
# np.int64(62000)

# %%
#Print 6 employe details
df.loc[0:5]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0         1001   Aarav         IT   55000           2
# 1         1002    Diya         HR   48000           1
# 2         1003   Rohan    Finance   62000           4
# 3         1004   Anaya         IT   70000           5
# 4         1005  Vivaan      Sales   45000           1
# 5         1006  Ishita         HR   52000           3

# %% [markdown]
# #Filtering with conditions

# %%
df
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0         1001   Aarav         IT   55000           2
# 1         1002    Diya         HR   48000           1
# 2         1003   Rohan    Finance   62000           4
# 3         1004   Anaya         IT   70000           5
# 4         1005  Vivaan      Sales   45000           1
# 5         1006  Ishita         HR   52000           3
# 6         1007  Aditya    Finance   68000           4
# 7         1008    Myra  Marketing   58000           2
# 8         1009   Arjun         IT   75000           6
# 9         1010   Kiara      Sales   50000           2

# %%
#Whose salary is greaterthan 60000
df[df["Salary"] > 60000]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 2         1003   Rohan    Finance   62000           4
# 3         1004   Anaya         IT   70000           5
# 6         1007  Aditya    Finance   68000           4
# 8         1009   Arjun         IT   75000           6

# %%
#who employe work IT department 
df[df["Department"] == "IT"]
# Out:
#    Employee_ID   Name Department  Salary  Experience
# 0         1001  Aarav         IT   55000           2
# 3         1004  Anaya         IT   70000           5
# 8         1009  Arjun         IT   75000           6

# %%
#Whose employees 3 year experience
df[df["Experience"] >=3]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 2         1003   Rohan    Finance   62000           4
# 3         1004   Anaya         IT   70000           5
# 5         1006  Ishita         HR   52000           3
# 6         1007  Aditya    Finance   68000           4
# 8         1009   Arjun         IT   75000           6

# %%
#Whose salary less than 50000
df[df["Salary"] < 50000]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 1         1002    Diya         HR   48000           1
# 4         1005  Vivaan      Sales   45000           1

# %%
#Who work in the IT Department and salary is 60000 up
df[(df["Department"] == "IT") & (df["Salary"] >= 60000)]
# Out:
#    Employee_ID   Name Department  Salary  Experience
# 3         1004  Anaya         IT   70000           5
# 8         1009  Arjun         IT   75000           6

# %%
#Who work in the HR or Sales department 
df[(df["Department"] == "HR") | (df["Department"] == "Sales")]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 1         1002    Diya         HR   48000           1
# 4         1005  Vivaan      Sales   45000           1
# 5         1006  Ishita         HR   52000           3
# 9         1010   Kiara      Sales   50000           2

# %%
#Who have more than 2 year experience and salary 55000 up 
df[(df["Experience"] >= 2) & (df["Salary"] >= 55000)]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0         1001   Aarav         IT   55000           2
# 2         1003   Rohan    Finance   62000           4
# 3         1004   Anaya         IT   70000           5
# 6         1007  Aditya    Finance   68000           4
# 7         1008    Myra  Marketing   58000           2
# 8         1009   Arjun         IT   75000           6

# %%
#Who work in the IT department and have more than 3 years of experience
df[(df["Department"] == "IT" ) & (df["Experience"] >= 3)]
# Out:
#    Employee_ID   Name Department  Salary  Experience
# 3         1004  Anaya         IT   70000           5
# 8         1009  Arjun         IT   75000           6

# %%
#Whose salary is between 50000 and 70000
df[(df["Salary"] > 50000) & (df["Salary"] < 70000)]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0         1001   Aarav         IT   55000           2
# 2         1003   Rohan    Finance   62000           4
# 5         1006  Ishita         HR   52000           3
# 6         1007  Aditya    Finance   68000           4
# 7         1008    Myra  Marketing   58000           2

# %%
#Who work in the Finance department and salary is 60000 up
df[(df["Department"] == "Finance") & (df["Salary"] >= 60000)]
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 2         1003   Rohan    Finance   62000           4
# 6         1007  Aditya    Finance   68000           4

# %% [markdown]
# #New_Data

# %%
df1 = pd.read_excel(r"C:\Users\Ridhi Rathore\Downloads\Power_Query_Practice_Data.xlsx")
df1
# Out:
#    OrderID        Date Customer       City   Category      Product  Qty  \
# 0     1001  2026-01-05     Amit  Ahmedabad     Mobile  Samsung A56    2
# 1     1002  2026-01-06     Neha      Surat     Laptop        HP 15    1
# 2     1003  2026-01-07      Raj   Vadodara  Accessory        Mouse    3
# 3     1004  2026-01-08    Pooja     Rajkot     Mobile    iPhone 15    1
# 4     1005  2026-01-09    Karan  Ahmedabad     Tablet         iPad    2
# 5     1006  2026-01-10    Meera      Surat     Laptop       Lenovo    1
# 6     1007  2026-01-11    Vikas  Bhavnagar  Accessory     Keyboard    4
# 7     1008  2026-01-12     Riya  Ahmedabad     Mobile      OnePlus    2
# 8     1009  2026-01-13    Arjun      Surat     Tablet  Samsung Tab    1
# 9     1010  2026-01-14    Nisha     Rajkot  Accessory   Headphones    5
#
#    Price  Discount Payment
# 0  25000        10     UPI
# 1  52000         5    Card
# 2    800         0    Cash
# 3  70000         8    Card
# 4  35000        12     UPI
# ...

# %%
#Select only Category columns
df1["Category"]
# Out:
# 0       Mobile
# 1       Laptop
# 2    Accessory
# 3       Mobile
# 4       Tablet
# 5       Laptop
# 6    Accessory
# 7       Mobile
# 8       Tablet
# 9    Accessory
# Name: Category, dtype: object

# %%
#Select 4 columns Order-id,Date,name,product 
df1[["OrderID","Date","Customer","Product"]]
# Out:
#    OrderID        Date Customer      Product
# 0     1001  2026-01-05     Amit  Samsung A56
# 1     1002  2026-01-06     Neha        HP 15
# 2     1003  2026-01-07      Raj        Mouse
# 3     1004  2026-01-08    Pooja    iPhone 15
# 4     1005  2026-01-09    Karan         iPad
# 5     1006  2026-01-10    Meera       Lenovo
# 6     1007  2026-01-11    Vikas     Keyboard
# 7     1008  2026-01-12     Riya      OnePlus
# 8     1009  2026-01-13    Arjun  Samsung Tab
# 9     1010  2026-01-14    Nisha   Headphones

# %%
df1.loc[0]
# Out:
# OrderID            1001
# Date         2026-01-05
# Customer           Amit
# City          Ahmedabad
# Category         Mobile
# Product     Samsung A56
# Qty                   2
# Price             25000
# Discount             10
# Payment             UPI
# Name: 0, dtype: object

# %%
df1.loc[0:5,["Customer","Product"]]
# Out:
#   Customer      Product
# 0     Amit  Samsung A56
# 1     Neha        HP 15
# 2      Raj        Mouse
# 3    Pooja    iPhone 15
# 4    Karan         iPad
# 5    Meera       Lenovo

# %%
df1.iloc[0:5,0:6]
# Out:
#    OrderID        Date Customer       City   Category      Product
# 0     1001  2026-01-05     Amit  Ahmedabad     Mobile  Samsung A56
# 1     1002  2026-01-06     Neha      Surat     Laptop        HP 15
# 2     1003  2026-01-07      Raj   Vadodara  Accessory        Mouse
# 3     1004  2026-01-08    Pooja     Rajkot     Mobile    iPhone 15
# 4     1005  2026-01-09    Karan  Ahmedabad     Tablet         iPad

# %%
#Only orderid Date customer product columns access use iloc
df1.iloc[0:5,[0,1,2,5]]
# Out:
#    OrderID        Date Customer      Product
# 0     1001  2026-01-05     Amit  Samsung A56
# 1     1002  2026-01-06     Neha        HP 15
# 2     1003  2026-01-07      Raj        Mouse
# 3     1004  2026-01-08    Pooja    iPhone 15
# 4     1005  2026-01-09    Karan         iPad

# %%
#select only customer name  use at 
df1.at[0,"Customer"]
df1.at[4,"Product"]
# Out:
# 'iPad'

# %%
#use iat access raj name 
df1.iat[2,2]
# Out:
# 'Raj'

# %%
df1
# Out:
#    OrderID        Date Customer       City   Category      Product  Qty  \
# 0     1001  2026-01-05     Amit  Ahmedabad     Mobile  Samsung A56    2
# 1     1002  2026-01-06     Neha      Surat     Laptop        HP 15    1
# 2     1003  2026-01-07      Raj   Vadodara  Accessory        Mouse    3
# 3     1004  2026-01-08    Pooja     Rajkot     Mobile    iPhone 15    1
# 4     1005  2026-01-09    Karan  Ahmedabad     Tablet         iPad    2
# 5     1006  2026-01-10    Meera      Surat     Laptop       Lenovo    1
# 6     1007  2026-01-11    Vikas  Bhavnagar  Accessory     Keyboard    4
# 7     1008  2026-01-12     Riya  Ahmedabad     Mobile      OnePlus    2
# 8     1009  2026-01-13    Arjun      Surat     Tablet  Samsung Tab    1
# 9     1010  2026-01-14    Nisha     Rajkot  Accessory   Headphones    5
#
#    Price  Discount Payment
# 0  25000        10     UPI
# 1  52000         5    Card
# 2    800         0    Cash
# 3  70000         8    Card
# 4  35000        12     UPI
# ...

# %% [markdown]
# #Revison

# %%
df = pd.read_csv(r"C:\Users\Ridhi Rathore\Downloads\small_sales_eda_practice.csv")
df
# Out:
#     Order_ID Customer       City     Category     Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics      Laptop         1   55000
# 1        102    Priya     Mumbai     Clothing       Jeans         2    3600
# 2        103     Amit      Delhi      Grocery        Rice         5    4500
# 3        104     Neha  Ahmedabad  Electronics       Mouse         3    2400
# 4        105    Karan      Surat     Clothing     T-Shirt         4    2800
# 5        106     Riya     Mumbai  Electronics    Keyboard         2    3000
# 6        107    Mohit      Delhi      Grocery         Oil         3    4500
# 7        108   Anjali  Ahmedabad    Furniture       Chair         4   10000
# 8        109      Raj      Surat  Electronics  Headphones         2    4400
# 9        110   Simran     Mumbai     Clothing       Jeans         3    5400
# 10       111      Dev  Ahmedabad  Electronics      Laptop         2  110000
# ...

# %% [raw]
# #Data selection

# %%
#Select the customer name column
df["Customer"]
# Out:
# 0      Rahul
# 1      Priya
# 2       Amit
# 3       Neha
# 4      Karan
# 5       Riya
# 6      Mohit
# 7     Anjali
# 8        Raj
# 9     Simran
# 10       Dev
# 11     Meena
# 12     Arjun
# 13     Pooja
# 14     Rohan
# Name: Customer, dtype: object

# %%
#Select customer name and city 
df[["Customer","City"]]
# Out:
#    Customer       City
# 0     Rahul  Ahmedabad
# 1     Priya     Mumbai
# 2      Amit      Delhi
# 3      Neha  Ahmedabad
# 4     Karan      Surat
# 5      Riya     Mumbai
# 6     Mohit      Delhi
# 7    Anjali  Ahmedabad
# 8       Raj      Surat
# 9    Simran     Mumbai
# 10      Dev  Ahmedabad
# 11    Meena      Delhi
# 12    Arjun      Surat
# 13    Pooja  Ahmedabad
# 14    Rohan     Mumbai

# %%
#Select product,quentity,sales columns
df[["Product","Quantity","Sales"]]
# Out:
#        Product  Quantity   Sales
# 0       Laptop         1   55000
# 1        Jeans         2    3600
# 2         Rice         5    4500
# 3        Mouse         3    2400
# 4      T-Shirt         4    2800
# 5     Keyboard         2    3000
# 6          Oil         3    4500
# 7        Chair         4   10000
# 8   Headphones         2    4400
# 9        Jeans         3    5400
# 10      Laptop         2  110000
# 11       Table         1    6500
# 12        Rice         6    5400
# 13     T-Shirt         5    3500
# 14      Tablet         2   50000

# %% [raw]
# #Selecting rows

# %%
#Select the customer at index 3
df.loc[3]
# Out:
# Order_ID            104
# Customer           Neha
# City          Ahmedabad
# Category    Electronics
# Product           Mouse
# Quantity              3
# Sales              2400
# Rating              4.2
# Name: 3, dtype: object

# %%
#Select first 5 rows only customer name and sales 
df.loc[0:4,["Customer","Sales"]]
# Out:
#   Customer  Sales
# 0    Rahul  55000
# 1    Priya   3600
# 2     Amit   4500
# 3     Neha   2400
# 4    Karan   2800

# %%
#print all ahmedabad rows use only loc fundtion
df.loc[df["City"] == "Ahmedabad"]
# Out:
#     Order_ID Customer       City     Category  Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics   Laptop         1   55000
# 3        104     Neha  Ahmedabad  Electronics    Mouse         3    2400
# 7        108   Anjali  Ahmedabad    Furniture    Chair         4   10000
# 10       111      Dev  Ahmedabad  Electronics   Laptop         2  110000
# 13       114    Pooja  Ahmedabad     Clothing  T-Shirt         5    3500
#
#     Rating
# 0      4.5
# 3      4.2
# 7      4.6
# 10     4.7
# 13     4.4

# %%
#only print ahmedabad customer name and sales use only loc
df.loc[df["City"] == "Ahmedabad",["Customer","Sales"]]
# Out:
#    Customer   Sales
# 0     Rahul   55000
# 3      Neha    2400
# 7    Anjali   10000
# 10      Dev  110000
# 13    Pooja    3500

# %%
#Select first rows using iloc
df.iloc[0]
# Out:
# Order_ID            101
# Customer          Rahul
# City          Ahmedabad
# Category    Electronics
# Product          Laptop
# Quantity              1
# Sales             55000
# Rating              4.5
# Name: 0, dtype: object

# %%
#Slect the first 5 rows using iloc
df.iloc[0:5,:]
# Out:
#    Order_ID Customer       City     Category  Product  Quantity  Sales  Rating
# 0       101    Rahul  Ahmedabad  Electronics   Laptop         1  55000     4.5
# 1       102    Priya     Mumbai     Clothing    Jeans         2   3600     4.0
# 2       103     Amit      Delhi      Grocery     Rice         5   4500     3.5
# 3       104     Neha  Ahmedabad  Electronics    Mouse         3   2400     4.2
# 4       105    Karan      Surat     Clothing  T-Shirt         4   2800     4.8

# %%
#select rows 2 to 6 and columns only customer name and product name 
df.iloc[2:7,[1,4]]
# Out:
#   Customer   Product
# 2     Amit      Rice
# 3     Neha     Mouse
# 4    Karan   T-Shirt
# 5     Riya  Keyboard
# 6    Mohit       Oil

# %%
#Select the last 3 rows and using iloc
df.iloc[-3:]
# Out:
#     Order_ID Customer       City     Category  Product  Quantity  Sales  \
# 12       113    Arjun      Surat      Grocery     Rice         6   5400
# 13       114    Pooja  Ahmedabad     Clothing  T-Shirt         5   3500
# 14       115    Rohan     Mumbai  Electronics   Tablet         2  50000
#
#     Rating
# 12     3.6
# 13     4.4
# 14     4.5

# %%
#Get the customer name at index 5 
df.at[5,"Customer"]
# Out:
# 'Riya'

# %%
#Get the sales value at index 10 
df.at[10,"Sales"]
# Out:
# np.int64(110000)

# %%
#Get the value from row 5 and column 2
df.iat[5,2]
# Out:
# 'Mumbai'

# %%
#Get the value from row 10 and column quentity 
df.iat[10,5]
# Out:
# np.int64(2)

# %% [raw]
# #Filtering

# %%
#Find all order where sales 10000 up 
df[df["Sales"] >= 10000]
# Out:
#     Order_ID Customer       City     Category Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics  Laptop         1   55000
# 7        108   Anjali  Ahmedabad    Furniture   Chair         4   10000
# 10       111      Dev  Ahmedabad  Electronics  Laptop         2  110000
# 14       115    Rohan     Mumbai  Electronics  Tablet         2   50000
#
#     Rating
# 0      4.5
# 7      4.6
# 10     4.7
# 14     4.5

# %%
#Find all orders where quentity 4 up
df[df["Quantity"] >=4]
# Out:
#     Order_ID Customer       City   Category  Product  Quantity  Sales  Rating
# 2        103     Amit      Delhi    Grocery     Rice         5   4500     3.5
# 4        105    Karan      Surat   Clothing  T-Shirt         4   2800     4.8
# 7        108   Anjali  Ahmedabad  Furniture    Chair         4  10000     4.6
# 12       113    Arjun      Surat    Grocery     Rice         6   5400     3.6
# 13       114    Pooja  Ahmedabad   Clothing  T-Shirt         5   3500     4.4

# %%
#Find all Electronics orders 
df[df["Category"] == "Electronics"]
# Out:
#     Order_ID Customer       City     Category     Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics      Laptop         1   55000
# 3        104     Neha  Ahmedabad  Electronics       Mouse         3    2400
# 5        106     Riya     Mumbai  Electronics    Keyboard         2    3000
# 8        109      Raj      Surat  Electronics  Headphones         2    4400
# 10       111      Dev  Ahmedabad  Electronics      Laptop         2  110000
# 14       115    Rohan     Mumbai  Electronics      Tablet         2   50000
#
#     Rating
# 0      4.5
# 3      4.2
# 5      4.1
# 8      4.3
# 10     4.7
# 14     4.5

# %%
#Find all orders from ahmedabad 
df[df["City"] == "Ahmedabad"]
# Out:
#     Order_ID Customer       City     Category  Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics   Laptop         1   55000
# 3        104     Neha  Ahmedabad  Electronics    Mouse         3    2400
# 7        108   Anjali  Ahmedabad    Furniture    Chair         4   10000
# 10       111      Dev  Ahmedabad  Electronics   Laptop         2  110000
# 13       114    Pooja  Ahmedabad     Clothing  T-Shirt         5    3500
#
#     Rating
# 0      4.5
# 3      4.2
# 7      4.6
# 10     4.7
# 13     4.4

# %%
#Find orders where sales up 10000 and rating is 4.5 up 
df[(df["Sales"] >= 10000 ) & (df["Rating"] >= 4.5)]
# Out:
#     Order_ID Customer       City     Category Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics  Laptop         1   55000
# 7        108   Anjali  Ahmedabad    Furniture   Chair         4   10000
# 10       111      Dev  Ahmedabad  Electronics  Laptop         2  110000
# 14       115    Rohan     Mumbai  Electronics  Tablet         2   50000
#
#     Rating
# 0      4.5
# 7      4.6
# 10     4.7
# 14     4.5

# %%
#Find orders where city is mumbai or surat 
df[(df["City"] == "Mumbai") | (df["City"] == "Surat")]
# Out:
#     Order_ID Customer    City     Category     Product  Quantity  Sales  \
# 1        102    Priya  Mumbai     Clothing       Jeans         2   3600
# 4        105    Karan   Surat     Clothing     T-Shirt         4   2800
# 5        106     Riya  Mumbai  Electronics    Keyboard         2   3000
# 8        109      Raj   Surat  Electronics  Headphones         2   4400
# 9        110   Simran  Mumbai     Clothing       Jeans         3   5400
# 12       113    Arjun   Surat      Grocery        Rice         6   5400
# 14       115    Rohan  Mumbai  Electronics      Tablet         2  50000
#
#     Rating
# 1      4.0
# 4      4.8
# 5      4.1
# 8      4.3
# 9      3.9
# 12     3.6
# 14     4.5

# %% [raw]
# #Query method

# %%
#Find orders where sales up to 12000 
df.query("Sales >= 12000")
# Out:
#     Order_ID Customer       City     Category Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics  Laptop         1   55000
# 10       111      Dev  Ahmedabad  Electronics  Laptop         2  110000
# 14       115    Rohan     Mumbai  Electronics  Tablet         2   50000
#
#     Rating
# 0      4.5
# 10     4.7
# 14     4.5

# %%
#Find Clothing orders 
df.query("Category == 'Clothing'")
# Out:
#     Order_ID Customer       City  Category  Product  Quantity  Sales  Rating
# 1        102    Priya     Mumbai  Clothing    Jeans         2   3600     4.0
# 4        105    Karan      Surat  Clothing  T-Shirt         4   2800     4.8
# 9        110   Simran     Mumbai  Clothing    Jeans         3   5400     3.9
# 13       114    Pooja  Ahmedabad  Clothing  T-Shirt         5   3500     4.4

# %%
#Find clothing high sales orders 
df.query("Category == 'Clothing'").max()
# Out:
# Order_ID         114
# Customer      Simran
# City           Surat
# Category    Clothing
# Product      T-Shirt
# Quantity           5
# Sales           5400
# Rating           4.8
# dtype: object

# %%
#Find orders where quentity is 4 up and rating is 4.0 to up 
df.query("Quantity >= 4 and Rating >= 4.5")
# Out:
#    Order_ID Customer       City   Category  Product  Quantity  Sales  Rating
# 4       105    Karan      Surat   Clothing  T-Shirt         4   2800     4.8
# 7       108   Anjali  Ahmedabad  Furniture    Chair         4  10000     4.6

# %%
#Find Mumbai orders with sales 5000 up 
df.query("City == 'Mumbai' and Sales >= 5000")
# Out:
#     Order_ID Customer    City     Category Product  Quantity  Sales  Rating
# 9        110   Simran  Mumbai     Clothing   Jeans         3   5400     3.9
# 14       115    Rohan  Mumbai  Electronics  Tablet         2  50000     4.5

# %%
#Select only customer city and sales columns 
df[["Customer","City","Sales"]]
# Out:
#    Customer       City   Sales
# 0     Rahul  Ahmedabad   55000
# 1     Priya     Mumbai    3600
# 2      Amit      Delhi    4500
# 3      Neha  Ahmedabad    2400
# 4     Karan      Surat    2800
# 5      Riya     Mumbai    3000
# 6     Mohit      Delhi    4500
# 7    Anjali  Ahmedabad   10000
# 8       Raj      Surat    4400
# 9    Simran     Mumbai    5400
# 10      Dev  Ahmedabad  110000
# 11    Meena      Delhi    6500
# 12    Arjun      Surat    5400
# 13    Pooja  Ahmedabad    3500
# 14    Rohan     Mumbai   50000

# %%
#Select first 7 rows and only product and sales columns 
df.loc[0:7,["Product","Sales"]]
# Out:
#     Product  Sales
# 0    Laptop  55000
# 1     Jeans   3600
# 2      Rice   4500
# 3     Mouse   2400
# 4   T-Shirt   2800
# 5  Keyboard   3000
# 6       Oil   4500
# 7     Chair  10000

# %%
#Select customer and rating for all orders from mumbai 
df.loc[df["City"] == "Mumbai",["City","Customer","Product","Rating"]]
# Out:
#       City Customer   Product  Rating
# 1   Mumbai    Priya     Jeans     4.0
# 5   Mumbai     Riya  Keyboard     4.1
# 9   Mumbai   Simran     Jeans     3.9
# 14  Mumbai    Rohan    Tablet     4.5

# %%
#Find all orders where sales is 5000 up and quantity 2 up
df[(df["Sales"] >= 5000) & (df["Quantity"] >= 2)]
# Out:
#     Order_ID Customer       City     Category Product  Quantity   Sales  \
# 7        108   Anjali  Ahmedabad    Furniture   Chair         4   10000
# 9        110   Simran     Mumbai     Clothing   Jeans         3    5400
# 10       111      Dev  Ahmedabad  Electronics  Laptop         2  110000
# 12       113    Arjun      Surat      Grocery    Rice         6    5400
# 14       115    Rohan     Mumbai  Electronics  Tablet         2   50000
#
#     Rating
# 7      4.6
# 9      3.9
# 10     4.7
# 12     3.6
# 14     4.5

# %%
#Find all electronics orders where rating is 4.5 to up
df.query("Category == 'Electronics' and Rating >= 4.5")
# Out:
#     Order_ID Customer       City     Category Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics  Laptop         1   55000
# 10       111      Dev  Ahmedabad  Electronics  Laptop         2  110000
# 14       115    Rohan     Mumbai  Electronics  Tablet         2   50000
#
#     Rating
# 0      4.5
# 10     4.7
# 14     4.5

# %%
#Find orders from Ahmedabad and surat 
df.query("City == 'Ahmedabad' or City == 'Surat'")
# Out:
#     Order_ID Customer       City     Category     Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics      Laptop         1   55000
# 3        104     Neha  Ahmedabad  Electronics       Mouse         3    2400
# 4        105    Karan      Surat     Clothing     T-Shirt         4    2800
# 7        108   Anjali  Ahmedabad    Furniture       Chair         4   10000
# 8        109      Raj      Surat  Electronics  Headphones         2    4400
# 10       111      Dev  Ahmedabad  Electronics      Laptop         2  110000
# 12       113    Arjun      Surat      Grocery        Rice         6    5400
# 13       114    Pooja  Ahmedabad     Clothing     T-Shirt         5    3500
#
#     Rating
# 0      4.5
# 3      4.2
# 4      4.8
# 7      4.6
# 8      4.3
# 10     4.7
# 12     3.6
# 13     4.4

# %%
#Find orders where sales 15000 up and rating is 4 up 
df.query("Sales >= 15000 and Rating >= 4.0")
# Out:
#     Order_ID Customer       City     Category Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics  Laptop         1   55000
# 10       111      Dev  Ahmedabad  Electronics  Laptop         2  110000
# 14       115    Rohan     Mumbai  Electronics  Tablet         2   50000
#
#     Rating
# 0      4.5
# 10     4.7
# 14     4.5

# %%
#Find clothing orders with quantity is 3 to up 
df.query("Category == 'Clothing' and Quantity >= 3")
# Out:
#     Order_ID Customer       City  Category  Product  Quantity  Sales  Rating
# 4        105    Karan      Surat  Clothing  T-Shirt         4   2800     4.8
# 9        110   Simran     Mumbai  Clothing    Jeans         3   5400     3.9
# 13       114    Pooja  Ahmedabad  Clothing  T-Shirt         5   3500     4.4

# %%
#Find jeans sales and rating 
df.query("Product == 'Jeans'")
# Out:
#    Order_ID Customer    City  Category Product  Quantity  Sales  Rating
# 1       102    Priya  Mumbai  Clothing   Jeans         2   3600     4.0
# 9       110   Simran  Mumbai  Clothing   Jeans         3   5400     3.9

# %%
#Select 3 to 8 rows and columns 1 to 5 
df.iloc[3:9,1:6]
# Out:
#   Customer       City     Category     Product  Quantity
# 3     Neha  Ahmedabad  Electronics       Mouse         3
# 4    Karan      Surat     Clothing     T-Shirt         4
# 5     Riya     Mumbai  Electronics    Keyboard         2
# 6    Mohit      Delhi      Grocery         Oil         3
# 7   Anjali  Ahmedabad    Furniture       Chair         4
# 8      Raj      Surat  Electronics  Headphones         2

# %%
df.query("City == 'Ahmedabad' and Sales >= 10000 and Rating >= 4.5")
# Out:
#     Order_ID Customer       City     Category Product  Quantity   Sales  \
# 0        101    Rahul  Ahmedabad  Electronics  Laptop         1   55000
# 7        108   Anjali  Ahmedabad    Furniture   Chair         4   10000
# 10       111      Dev  Ahmedabad  Electronics  Laptop         2  110000
#
#     Rating
# 0      4.5
# 7      4.6
# 10     4.7
